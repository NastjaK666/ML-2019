# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data = pd.read_csv('glass.data.txt', sep=",")

# %%
data.head()
# Out:
#    ID  refractive index     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0   1           1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2           1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3           1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4           1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5           1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Type of glass
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
data.shape
# Out:
# (214, 11)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 214

# %%
data.columns
# Out:
# Index(['ID', 'refractive index', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe',
#        'Type of glass'],
#       dtype='object')

# %%
data.dtypes
# Out:
# ID                    int64
# refractive index    float64
# Na                  float64
# Mg                  float64
# Al                  float64
# Si                  float64
# K                   float64
# Ca                  float64
# Ba                  float64
# Fe                  float64
# Type of glass         int64
# dtype: object

# %%
for col in data.columns:
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# ID - 0
# refractive index - 0
# Na - 0
# Mg - 0
# Al - 0
# Si - 0
# K - 0
# Ca - 0
# Ba - 0
# Fe - 0
# Type of glass - 0

# %%
data.describe()
# Out:
#                ID  refractive index          Na          Mg          Al  \
# count  214.000000        214.000000  214.000000  214.000000  214.000000
# mean   107.500000          1.518365   13.407850    2.684533    1.444907
# std     61.920648          0.003037    0.816604    1.442408    0.499270
# min      1.000000          1.511150   10.730000    0.000000    0.290000
# 25%     54.250000          1.516523   12.907500    2.115000    1.190000
# 50%    107.500000          1.517680   13.300000    3.480000    1.360000
# 75%    160.750000          1.519157   13.825000    3.600000    1.630000
# max    214.000000          1.533930   17.380000    4.490000    3.500000
#
#                Si           K          Ca          Ba          Fe  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean    72.650935    0.497056    8.956963    0.175047    0.057009
# std      0.774546    0.652192    1.423153    0.497219    0.097439
# ...

# %%
data['Type of glass'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='refractive index', y='Ca', data=data, hue = "Type of glass")

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['refractive index'])
# Out:
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='refractive index', y='Ca', data=data)

# %%
sns.jointplot(x='refractive index', y='Ca', data=data, kind = "hex")

# %%
sns.jointplot(x='refractive index', y='Ca', data=data, kind = "kde")

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue="Type of glass")
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Anaconda\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
sns.boxplot(x='Type of glass', y='refractive index', data=data)

# %%
sns.violinplot(x='Type of glass', y='refractive index', data=data)

# %%
data.corr()
# Out:
#                         ID  refractive index        Na        Mg        Al  \
# ID                1.000000         -0.072209  0.375722 -0.650328  0.490113
# refractive index -0.072209          1.000000 -0.191885 -0.122274 -0.407326
# Na                0.375722         -0.191885  1.000000 -0.273732  0.156794
# Mg               -0.650328         -0.122274 -0.273732  1.000000 -0.481799
# Al                0.490113         -0.407326  0.156794 -0.481799  1.000000
# Si                0.061232         -0.542052 -0.069809 -0.165927 -0.005524
# K                 0.003149         -0.289833 -0.266087  0.005396  0.325958
# Ca                0.090800          0.810403 -0.275442 -0.443750 -0.259592
# Ba                0.451001         -0.000386  0.326603 -0.492262  0.479404
# Fe               -0.072794          0.143010 -0.241346  0.083060 -0.074402
# Type of glass     0.877357         -0.164237  0.502898 -0.744993  0.598829
#
# ...

# %%
data.corr(method='pearson')
# Out:
#                         ID  refractive index        Na        Mg        Al  \
# ID                1.000000         -0.072209  0.375722 -0.650328  0.490113
# refractive index -0.072209          1.000000 -0.191885 -0.122274 -0.407326
# Na                0.375722         -0.191885  1.000000 -0.273732  0.156794
# Mg               -0.650328         -0.122274 -0.273732  1.000000 -0.481799
# Al                0.490113         -0.407326  0.156794 -0.481799  1.000000
# Si                0.061232         -0.542052 -0.069809 -0.165927 -0.005524
# K                 0.003149         -0.289833 -0.266087  0.005396  0.325958
# Ca                0.090800          0.810403 -0.275442 -0.443750 -0.259592
# Ba                0.451001         -0.000386  0.326603 -0.492262  0.479404
# Fe               -0.072794          0.143010 -0.241346  0.083060 -0.074402
# Type of glass     0.877357         -0.164237  0.502898 -0.744993  0.598829
#
# ...

# %%
data.corr(method='kendall')
# Out:
#                         ID  refractive index        Na        Mg        Al  \
# ID                1.000000         -0.052697  0.267788 -0.423014  0.332939
# refractive index -0.052697          1.000000  0.032005  0.104091 -0.355663
# Na                0.267788          0.032005  1.000000 -0.070483  0.077183
# Mg               -0.423014          0.104091 -0.070483  1.000000 -0.382292
# Al                0.332939         -0.355663  0.077183 -0.382292  1.000000
# Si                0.055289         -0.394753 -0.225544 -0.249138  0.141514
# K                -0.181831         -0.230818 -0.445621  0.124223  0.139882
# Ca                0.112580          0.528214  0.003880 -0.213563 -0.221124
# Ba                0.402640         -0.140011  0.322975 -0.367039  0.367202
# Fe               -0.069535          0.071797 -0.172392  0.070953 -0.057741
# Type of glass     0.860351         -0.158028  0.301438 -0.456691  0.441657
#
# ...

# %%
data.corr(method='spearman')
# Out:
#                         ID  refractive index        Na        Mg        Al  \
# ID                1.000000         -0.103903  0.398359 -0.569604  0.488819
# refractive index -0.103903          1.000000  0.031040  0.144156 -0.491821
# Na                0.398359          0.031040  1.000000 -0.126451  0.135910
# Mg               -0.569604          0.144156 -0.126451  1.000000 -0.512420
# Al                0.488819         -0.491821  0.135910 -0.512420  1.000000
# Si                0.088513         -0.525733 -0.265643 -0.336811  0.196513
# K                -0.272759         -0.288001 -0.584503  0.200742  0.153438
# Ca                0.142149          0.703777  0.027205 -0.289119 -0.280952
# Ba                0.507778         -0.181511  0.411111 -0.456107  0.474564
# Fe               -0.095743          0.096181 -0.217631  0.095487 -0.076313
# Type of glass     0.957570         -0.212936  0.398682 -0.589854  0.560148
#
# ...

# %%
fig, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(15,5))
sns.heatmap(data.corr(method='pearson'), ax=ax[0], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='kendall'), ax=ax[1], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='spearman'), ax=ax[2], annot=True, fmt='.2f')
fig.suptitle('Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')
